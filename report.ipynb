# %% [markdown]
# # <p style="text-align:center;"> Experiment M12e: Coupled pendurums and degree of coupling </p>
# ### <p style="text-align:center;"> Srinath Raghu - 3790570, Shu Nomura - 3763432 </P>
# ### <p style="text-align:center;"> Group: 12 </P>
# ### <p style="text-align:right;"> 25.01.2026 </p>

# %% [markdown]
# ## 1.Introduction

# %% [markdown]
# ## 2.Theoretical Background
# ### 2.1 Motion of pendulum
# The coupled pendulum has several parameters to explain it's moton during the oscillation.</br>
# We define</br>
# - length of the pendulum ($L$)
# - spring constant ($k$)
# - Time period of in-phase oscillation ($T_{in}$)
# - Time period pf out-coming oscillation ($T_{out}$)
# - Time period of beat mode oscillation ($T$)
# - Weght of the mass ($m$)
# - Angular displacement from rest position (${\theta}$)
#
# There is one more important value we are looking for which is called "degree of coupling" ($\kappa$).</br>
# $$\kappa=\frac{{T_{in}}^2+{T_{out}}^2}{{T_{in}}^2-{T_{out}}^2}\tag{1}$$
# This value is used to derive the time period of out-phase oscillation.
# The value of time period for beat mode oscillation is theoretically calculated with
# $$T=\frac{T_{in}T_{out}}{T_{in}-T_{out}}\tag{1}$$
#
# Derivation of spring constant $k$ from experimantal values are as follows</br>
# Hooke's law
# $$F=kx\tag{1}$$
# $F$ = forgce exerted on the mass</br>
# $x$ = extention of the spring<br>
# $k$ = spring constant</br></br>
# Force exerted is gravity so that</br>
# $$mg=kx\tag{2}$$
#
# $$k=\frac{mg}{x}\tag{3}$$

# %% [markdown]
# ## 3.Experimental data and results
#
# ### 3.1 Spring constant of the spring
# First of all, spring constant is required to start any derivation about the time period of the coupled pendulums.
# We use (88888888888888) to derive constant value $k$ from our experimental data around extention of the spring against the weight acting on the spring.
# |Weight ($g$)|Position ($m$)|
# |--|----|
# |10|65.5|
# |20|61.8|
# |30|57.3|
# |40|53.3|
# |50|49.0|
# |60|45.2|
# |70|41.0|
# |80|37.1|
# |90|33.7|
# |100|29.2|
#
# Using these data, the spring constant is derived.
# $$k = 2.43 Nm^{-1}$$
#
# ### 3.2 Time periods of the oscillations

# %% [markdown]
# TIme periods of the two pendulums are measured for different height of the spring coupling the pendulums are calculated from the grapsh below.
#
# |length ($m$)|time period of in-phase ($s$)|time period of out-phase ($s$)|
# |-----|------|------|
# |0.282|1.8190|2.5180|
# |0.382|1.8208|2.4847|
# |0.482|1.8231|2.4338|
# |0.582|1.8193|2.3777|
# |0.682|1.8205|2.3057|
# |0.782|1.8228|2.2468|
# |0.882|1.8248|2.1744|
# |0.982|1.8187|2.0765|

# %% [markdown]
# Using the formula (2) first three values for expected timeperiod of beat mode oscillations are calculated.</br>
# Here we compare with experimental valuesfrom the experiment.
# |langth ($m$)|Theoretical value ($s$)|Experimental value ($s$)|
# |||
# |0.282|
# |0.382|
# |0.482|
